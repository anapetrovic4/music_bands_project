# %%
import pandas as pd
import re
from datetime import datetime

# %%
# Show all rows and cols
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## David Crosby

# %%
david_crosby_wiki = pd.read_csv('/content/drive/MyDrive/Eksplorativna analiza podataka sa Spotify-a/Wikipedia Web Scraping/Wikipedia Datasets/raw/wikipedia-david-crosby.csv')

# Format release_date to yyyy-dd-mm
david_crosby_wiki['release_date'] = pd.to_datetime(david_crosby_wiki['release_date'], format = '%B %d, %Y')
david_crosby_wiki['release_date'] = david_crosby_wiki['release_date'].dt.strftime('%Y-%d-%m')

# Clean track names from brackets
david_crosby_wiki['track'] = david_crosby_wiki['track'].str.replace(r'\s*\(.*?\)\s*', '', regex=True)

# Remove square brackets from 'recording_period'
pattern_brackets = r'\[\d+\]'
david_crosby_wiki['recording_period'] = david_crosby_wiki['recording_period'].str.replace(pattern_brackets, '', regex=True)

david_crosby_wiki.to_csv('wikipedia-david-crosby-v2.csv', index=False)
david_crosby_wiki

# %% [markdown]
# ## Stephen Stills

# %%
stephen_stills_wiki = pd.read_csv('/content/drive/MyDrive/Eksplorativna analiza podataka sa Spotify-a/Wikipedia Web Scraping/Wikipedia Datasets/raw/wikipedia-stephen-stills.csv')

# Remove excess albums (by other bands)
stephen_stills_wiki = stephen_stills_wiki[stephen_stills_wiki['album'] != 'Manassas']
stephen_stills_wiki = stephen_stills_wiki[stephen_stills_wiki['album'] != 'Down the Road']
stephen_stills_wiki = stephen_stills_wiki[stephen_stills_wiki['album'] != "Pieces"]
stephen_stills_wiki = stephen_stills_wiki[stephen_stills_wiki['album'] != "Pierced Arrow"]
stephen_stills_wiki = stephen_stills_wiki[stephen_stills_wiki['album'] != "Can't Get Enough"]

# Format 'release_date'. Remove duplicated dates in round brackets
pattern_date = r'\([^)]*\)'
stephen_stills_wiki['release_date'] = stephen_stills_wiki['release_date'].str.replace(pattern_date, '', regex=True)
stephen_stills_wiki['release_date'] = pd.to_datetime(stephen_stills_wiki['release_date'], dayfirst=True, errors='coerce')
stephen_stills_wiki['release_date'] = stephen_stills_wiki['release_date'].dt.strftime('%Y-%d-%m')
stephen_stills_wiki['release_date'] = stephen_stills_wiki['release_date'].fillna('2016-06-05') # fill rows missing with 2016-05-06

# Format 'recording period'. Remove recording locations. Remove word 'Late'
pattern_locations = r'^[^0-9]*$'
stephen_stills_wiki['recording_period'] = stephen_stills_wiki['recording_period'].str.replace(pattern_locations, '', regex=True)
stephen_stills_wiki['recording_period'] = stephen_stills_wiki['recording_period'].str.replace('Late', '', regex=False).str.strip()

# Remove square brackets from 'tracks'
pattern_brackets = r'\[\d+\]'
stephen_stills_wiki['track'] = stephen_stills_wiki['track'].str.replace(pattern_brackets, '', regex=True)

# Remove all parts in brackets that contain '(Later recorder' to get the original track title
stephen_stills_wiki['track'] = stephen_stills_wiki['track'].str.replace(r'\(Later recorded.*?\)', '', regex=True)

# Fill NaN values in 'vocals'
stephen_stills_wiki['vocals'] = stephen_stills_wiki['vocals'].fillna('Stephen Stills')

# Fill NaN values in 'writers'
stephen_stills_wiki['writers'] = stephen_stills_wiki['writers'].fillna('Stephen Stills')

# Remove duplicated tracks
stephen_stills_wiki = stephen_stills_wiki[stephen_stills_wiki['track'] != "Albert's Shuffle (2002 remix without horns)"] # 8	Albert's Shuffle (2002 remix without horns)
stephen_stills_wiki = stephen_stills_wiki[stephen_stills_wiki['track'] != "Season of the Witch (2002 remix without horns)"] # 9	Season of the Witch (2002 remix without horns)	Super Session

stephen_stills_wiki.reset_index(drop=True, inplace=True)

stephen_stills_wiki.to_csv('wikipedia-stephen-stills-v2.csv', index=False)

stephen_stills_wiki

# %% [markdown]
# ## Graham Nash

# %%
graham_nash_wiki = pd.read_csv('/content/drive/MyDrive/Eksplorativna analiza podataka sa Spotify-a/Wikipedia Web Scraping/Wikipedia Datasets/raw/wikipedia-graham-nash.csv')

# Remove excess albums (live, compilations, by other bands)
graham_nash_wiki = graham_nash_wiki[graham_nash_wiki['album'] != 'Stay with the Hollies']
graham_nash_wiki = graham_nash_wiki[graham_nash_wiki['album'] != 'In The Hollies Style']
graham_nash_wiki = graham_nash_wiki[graham_nash_wiki['album'] != 'Hollies']
graham_nash_wiki = graham_nash_wiki[graham_nash_wiki['album'] != 'The Hollies']
graham_nash_wiki = graham_nash_wiki[graham_nash_wiki['album'] != 'Would You Believe?']
graham_nash_wiki = graham_nash_wiki[graham_nash_wiki['album'] != 'Bus Stop']
graham_nash_wiki = graham_nash_wiki[graham_nash_wiki['album'] != 'For Certain Because']
graham_nash_wiki = graham_nash_wiki[graham_nash_wiki['album'] != 'Evolution']
graham_nash_wiki = graham_nash_wiki[graham_nash_wiki['album'] != 'Butterfly']
graham_nash_wiki = graham_nash_wiki[graham_nash_wiki['album'] != 'What Goes Around...']
graham_nash_wiki = graham_nash_wiki[graham_nash_wiki['album'] != 'Just One Look']
graham_nash_wiki = graham_nash_wiki[graham_nash_wiki['album'] != 'Here I Go Again']
graham_nash_wiki = graham_nash_wiki[graham_nash_wiki['album'] != "I'm Alive"]
graham_nash_wiki = graham_nash_wiki[graham_nash_wiki['album'] != "Over the Years"]

graham_nash_wiki.reset_index(drop=True, inplace=True)

# Format 'release_date'. Remove square and round brackets
pattern_brackets = r'\[\d+\]' # Remove square brackets
graham_nash_wiki['release_date'] = graham_nash_wiki['release_date'].str.replace(pattern_brackets, '', regex=True)
pattern_date = r'\([^)]*\)' # Remove round brackets
graham_nash_wiki['release_date'] = graham_nash_wiki['release_date'].str.replace(pattern_date, '', regex=True)

def convert_date_format(date_string):
  try:
        # Try to convert "Month YYYY" format
        return pd.to_datetime(date_string, format='%B %Y').strftime('%Y-%m')
  except ValueError:
        try:
            # Try to convert "YYYY" format
            return pd.to_datetime(date_string, format='%Y').strftime('%Y-%m')
        except ValueError:
            try:
                # Try to convert "Day Month YYYY" format
                return pd.to_datetime(date_string, format='%d %B %Y').strftime('%Y-%d-%m')
            except ValueError:
                return None

graham_nash_wiki['release_date'] = graham_nash_wiki['release_date'].apply(convert_date_format)

# Fill NaN values in 'vocals'
graham_nash_wiki['vocals'] = graham_nash_wiki['vocals'].fillna('Graham Nash')

# Fill NaN values in 'writers'
graham_nash_wiki['writers'] = graham_nash_wiki['writers'].fillna('Graham Nash')

# Fill NaN values in 'recording_period'
graham_nash_wiki['recording_period'] = graham_nash_wiki['recording_period'].fillna('')

# Remove location from 'recording_period' [0:8]
graham_nash_wiki.iloc[0:9, graham_nash_wiki.columns.get_loc('recording_period')] = graham_nash_wiki.iloc[0:9, graham_nash_wiki.columns.get_loc('recording_period')].str.slice(0, 4)

# Remove square brackets from 'recording_period'
graham_nash_wiki['recording_period'] = graham_nash_wiki['recording_period'].str.replace(pattern_brackets, '', regex=True)

# Remove square brackets from 'producers'
graham_nash_wiki['producers'] = graham_nash_wiki['producers'].str.replace(pattern_brackets, '', regex=True)

# Format producer names
graham_nash_wiki['producers'] = graham_nash_wiki['producers'].str.replace('NashTodd', 'Nash, Todd', regex=False)
graham_nash_wiki['producers'] = graham_nash_wiki['producers'].str.replace('Shane Fontayne,', 'Shane Fontayne', regex=False)

graham_nash_wiki.to_csv('wikipedia-graham-nash-v2.csv', index=False)
graham_nash_wiki

# %% [markdown]
# ## Neil Young

# %%
neil_young_wiki = pd.read_csv('/content/drive/MyDrive/Eksplorativna analiza podataka sa Spotify-a/Wikipedia Web Scraping/Wikipedia Datasets/raw/wikipedia-neil-young.csv')

# Remove excess albums (live, compilations, by other bands)
neil_young_wiki = neil_young_wiki[neil_young_wiki['album'] != 'Re·ac·tor']
neil_young_wiki = neil_young_wiki[neil_young_wiki['album'] != 'Life']
neil_young_wiki = neil_young_wiki[neil_young_wiki['album'] != 'Ragged Glory']
neil_young_wiki = neil_young_wiki[neil_young_wiki['album'] != 'Sleeps with Angels']
neil_young_wiki = neil_young_wiki[neil_young_wiki['album'] != 'Broken Arrow']
neil_young_wiki = neil_young_wiki[neil_young_wiki['album'] != 'Greendale']
neil_young_wiki = neil_young_wiki[neil_young_wiki['album'] != 'Americana']
neil_young_wiki = neil_young_wiki[neil_young_wiki['album'] != 'Psychedelic Pill']
neil_young_wiki = neil_young_wiki[neil_young_wiki['album'] != 'Colorado']
neil_young_wiki = neil_young_wiki[neil_young_wiki['album'] != 'World Record']
neil_young_wiki = neil_young_wiki[neil_young_wiki['album'] != 'Live Rust']
neil_young_wiki = neil_young_wiki[neil_young_wiki['album'] != 'Year of the Horse']
neil_young_wiki = neil_young_wiki[neil_young_wiki['album'] != "Fuckin' Up"]
neil_young_wiki = neil_young_wiki[neil_young_wiki['album'] != 'Way Down in the Rust Bucket']
neil_young_wiki = neil_young_wiki[neil_young_wiki['album'] != 'Toast']
neil_young_wiki = neil_young_wiki[neil_young_wiki['album'] != 'Odeon Budokan']
neil_young_wiki = neil_young_wiki[neil_young_wiki['album'] != 'Noise & Flowers']
neil_young_wiki = neil_young_wiki[neil_young_wiki['album'] != 'Tuscaloosa']
neil_young_wiki = neil_young_wiki[neil_young_wiki['album'] != 'The Monsanto Years']
neil_young_wiki = neil_young_wiki[neil_young_wiki['album'] != 'Are You Passionate?']

# Format 'release_date'. Remove square and round brackets
pattern_brackets = r'\[\d+\]' # Remove square brackets
neil_young_wiki['release_date'] = neil_young_wiki['release_date'].str.replace(pattern_brackets, '', regex=True)
pattern_date = r'\([^)]*\)' # Remove round brackets
neil_young_wiki['release_date'] = neil_young_wiki['release_date'].str.replace(pattern_date, '', regex=True)

# Format dates to yyyy-dd-mm in 'release_date'
neil_young_wiki['release_date'] = pd.to_datetime(neil_young_wiki['release_date'], format = '%B %d, %Y')
neil_young_wiki['release_date'] = neil_young_wiki['release_date'].dt.strftime('%Y-%d-%m')

# Remove locations from 'recording period'. Remove duplicated dates in 'recording_period'
neil_young_wiki['recording_period'] = neil_young_wiki['recording_period'].str.replace(pattern_date, '', regex=True)
# Remove square brackets from 'recording_period'
neil_young_wiki['recording_period'] = neil_young_wiki['recording_period'].str.replace(pattern_brackets, '', regex=True)

# Split by comma dates in 'recording_period'
neil_young_wiki['recording_period'] = neil_young_wiki['recording_period'].str.replace('June 2014', 'June 2014, ', regex=False)
neil_young_wiki['recording_period'] = neil_young_wiki['recording_period'].str.replace('November 4 – 7, 2016', 'November 4 – 7, 2016, ', regex=False)
neil_young_wiki['recording_period'] = neil_young_wiki['recording_period'].str.replace('June 9, 2017', 'June 9, 2017, ', regex=False)
neil_young_wiki['recording_period'] = neil_young_wiki['recording_period'].str.replace('March 28 – May 28, 2010', 'March 28 – May 28, 2010, ', regex=False)
neil_young_wiki['recording_period'] = neil_young_wiki['recording_period'].str.replace('October 10 – 12, 2011', 'October 10 – 12, 2011, ', regex=False)
neil_young_wiki['recording_period'] = neil_young_wiki['recording_period'].str.replace('January 28, 2019', 'January 28, 2019, ', regex=False)
neil_young_wiki['recording_period'] = neil_young_wiki['recording_period'].str.replace('February 4, 2019', 'February 4, 2019, ', regex=False)
neil_young_wiki['recording_period'] = neil_young_wiki['recording_period'].str.replace('November 8 – December 15, 2000', 'November 8 – December 15, 2000, ', regex=False)

# Remove square brackets from 'producers'
neil_young_wiki['producers'] = neil_young_wiki['producers'].str.replace(pattern_brackets, '', regex=True)

# Replace 'John Hanlon,' by 'John Hanlon' and 'Niko Bolas,' by 'Niko Bolas' in 'producers'
neil_young_wiki['producers'] = neil_young_wiki['producers'].str.replace('John Hanlon,', 'John Hanlon', regex=False)
neil_young_wiki['producers'] = neil_young_wiki['producers'].str.replace('Niko Bolas,', 'Niko Bolas', regex=False)

# Fill NaN in 'vocals'
neil_young_wiki['vocals'] = neil_young_wiki['vocals'].fillna('Neil Young')

# Fill NaN in 'writers'
neil_young_wiki['writers'] = neil_young_wiki['writers'].fillna('Neil Young')

# Remove duplicated tracks

neil_young_wiki.to_csv('wikipedia-neil-young-v2.csv', index=False)

neil_young_wiki

# %% [markdown]
# ## Crosby & Nash

# %%
crosby_nash_wiki = pd.read_csv('/content/drive/MyDrive/Eksplorativna analiza podataka sa Spotify-a/Wikipedia Web Scraping/Wikipedia Datasets/raw/wikipedia-cn.csv')

# Format dates to yyyy-dd-mm in 'release_date'
def convert_date_format(date_str):
    try:
        if ',' in date_str: # check if format is "Month digit, year"
            return datetime.strptime(date_str, '%B %d, %Y').strftime('%Y-%d-%m') # convert to desired date format
        else:
            return date_str # if only year is found, keep format 'yyyy'
    except ValueError:
        return date_str # if conversion isn't possible, return the original date

crosby_nash_wiki['release_date'] = crosby_nash_wiki['release_date'].apply(convert_date_format)

# Remove square brackets from 'track'
pattern_brackets = r'\[\d+\]' # Remove square brackets
crosby_nash_wiki['track'] = crosby_nash_wiki['track'].str.replace(pattern_brackets, '', regex=True)

# Fill NaN values in 'recording_period'
crosby_nash_wiki['recording_period'] = crosby_nash_wiki['recording_period'].fillna('')

# Fill NaN values in 'writers' and 'vocals'
crosby_nash_wiki['writers'] = crosby_nash_wiki['writers'].fillna('Crosby & Nash')
crosby_nash_wiki['vocals'] = crosby_nash_wiki['vocals'].fillna('Crosby & Nash')

# Remove location from 'recording_period'
crosby_nash_wiki = crosby_nash_wiki[~crosby_nash_wiki['recording_period'].str.lower().str.startswith('rudy')]
crosby_nash_wiki = crosby_nash_wiki[~crosby_nash_wiki['writers'].str.lower().str.startswith('traditional')]

crosby_nash_wiki.to_csv('wikipedia-crosby-nash-v2.csv', index=False)

crosby_nash_wiki

# %% [markdown]
# ##Crosby, Stills & Nash | Crosby, Stills, Nash & Young

# %%
csn_csny_wiki = pd.read_csv('/content/drive/MyDrive/Eksplorativna analiza podataka sa Spotify-a/Wikipedia Web Scraping/Wikipedia Datasets/raw/wikipedia-csn-csny.csv')

# Remove round brackets from 'release_date'
pattern_date = r'\([^)]*\)' # Remove round brackets
csn_csny_wiki['release_date'] = csn_csny_wiki['release_date'].str.replace(pattern_date, '', regex=True)

# Format dates to yyyy-dd-mm in 'release_date'
csn_csny_wiki['release_date'] = pd.to_datetime(csn_csny_wiki['release_date'], format = '%B %d, %Y')
csn_csny_wiki['release_date'] = csn_csny_wiki['release_date'].dt.strftime('%Y-%d-%m')

# Split by blank space dates in 'recording_period'
csn_csny_wiki['recording_period'] = csn_csny_wiki['recording_period'].str.replace('January1970', 'January 1970', regex=False)

# Replace ' with ' by comma in 'vocals'
csn_csny_wiki['vocals'] = csn_csny_wiki['vocals'].str.replace(' with ', ', ', regex=False)


# Remove duplicated tracks:
csn_csny_wiki = csn_csny_wiki[~csn_csny_wiki['track'].str.contains('mix', case=False)]
csn_csny_wiki = csn_csny_wiki[~csn_csny_wiki['track'].str.contains('alternate', case=False)]
csn_csny_wiki = csn_csny_wiki[~csn_csny_wiki['track'].str.contains('early version', case=False)]
csn_csny_wiki = csn_csny_wiki[~csn_csny_wiki['track'].str.contains('with harmonica', case=False)]

csn_csny_wiki.reset_index(drop=True, inplace=True)
csn_csny_wiki.to_csv('wikipedia-csn-csny-v2.csv', index=False)
csn_csny_wiki

# %% [markdown]
# ## Merge all DataFrames to 'wikipedia-v2.csv'

# %%
8stills_young_wiki = pd.read_csv('/content/drive/MyDrive/Eksplorativna analiza podataka sa Spotify-a/Wikipedia Web Scraping/Wikipedia Datasets/raw/wikipedia-stills-young-band.csv')
wikipedia_v2 = pd.concat([david_crosby_wiki,
                         stephen_stills_wiki,
                         graham_nash_wiki,
                         neil_young_wiki,
                         stills_young_wiki,
                         crosby_nash_wiki,
                         csn_csny_wiki
                         ]).reset_index(drop=True)
wikipedia_v2.to_csv('wikipedia-v2.csv', index=False)
wikipedia_v2
# Out:
#                                                  track  \
# 0                                         Drive My Car
# 1                                               Melody
# 2                              Monkey and the Underdog
# 3                                     In the Wide Ruin
# 4                                   Tracks in the Dust
# 5                                       Drop Down Mama
# 6                                   Lady of the Harbor
# 7                                            Distances
# 8                                           Flying Man
# 9                                         Oh Yes I Can
# 10                                                Hero
# 11                                    Too Young to Die
# 12                                         Old Soldier
# 13                                  Through Your Hands
# 14                                   Yvette in English
# 15                                      Thousand Roads
# 16                                            Columbus
# 17                                      Helpless Heart
# 18                                            Coverage
# 19                                       What's Broken
# 20                                         Time I Have
# 21                               Holding On to Nothing
# 22                                        The Clearing
# 23                                               Radio
# 24                                       Slice of Time
# 25                               Set That Baggage Down
# 26                                       If She Called
# 27                                     Dangerous Night
# 28                                     Morning Falling
# 29                               Things We Do for Love
# 30                                        The Us Below
# 31                             Drive Out to the Desert
# 32                                  Look in Their Eyes
# 33                             Somebody Other Than You
# 34                                            The City
# 35                                 Paint You a Picture
# 36                                    What Makes It So
# 37                           She's Got To Be Somewhere
# 38                                          Sky Trails
# 39                                   Sell Me a Diamond
# 40                       Before Tomorrow Falls on Love
# 41                             Here It's Almost Sunset
# 42                                             Capitol
# 43                                              Amelia
# 44                                       Somebody Home
# 45                                          Curved Air
# 46                                           Home Free
# 47                                               Glory
# 48                                  Vagrants of Venice
# 49                                                1974
# 50                                       Your Own Ride
# 51                                    Buddha on a Hill
# 52                                      I Am No Artist
# 53                                                1967
# 54                                   Balanced on a Pin
# 55                                     Other Half Rule
# 56                                               Janet
# 57                                          River Rise
# 58                                           I Think I
# 59                          The Other Side of Midnight
# 60                               Rodriguez for a Night
# 61                                       Secret Dancer
# 62                                  Ships in the Night
# 63                                            For Free
# 64                                               Boxes
# 65                                          Shot at Me
# 66                               I Won't Stay for Long
# 67                                    Albert's Shuffle
# 68                                                Stop
# 69                                    Man's Temptation
# 70                              His Holy Modal Majesty
# 71    It Takes a Lot to Laugh, It Takes a Train to Cry
# 72                                 Season of the Witch
# 73                                   You Don't Love Me
# 74                                       Harvey's Tune
# 75                         Blues for Nothing (outtake)
# 76                            Love the One You're With
# 77                                   Do for the Others
# 78                            Church (Part of Someone)
# 79                                Old Times Good Times
# 80                                   Sit Yourself Down
# 81                                          To a Flame
# 82                                         Black Queen
# 83                                            Cherokee
# 84                                 We Are Not Helpless
# 85                                     Change Partners
# 86                             Nothin' to Do but Today
# 87                                Fishes and Scorpions
# 88                                          Sugar Babe
# 89                                 Know You Got to Run
# 90                                       Relaxing Town
# 91                                        Singin' Call
# 92                                        Ecology Song
# 93                                           Word Game
# 94                                            Marianne
# 95                                  Bluebird Revisited
# 96                                 Turn Back the Pages
# 97                                 My Favorite Changes
# 98                                            My Angel
# 99                                          In the Way
# 100                                         Love Story
# 101                                 First Things First
# 102                                           New Mama
# 103                                   As I Come of Age
# 104                                Shuffle Just as Bad
# 105                                    Cold Cold World
# 106                                   Myth of Sisyphus
# 107                                       Wooden Ships
# 108                                     Four Days Gone
# 109  Jet Set (Sigh) /Rocky Mountain Way/Jet Set (Sigh)
# 110                                    Change Partners
# 111                      Crossroads/You Can't Catch Me
# 112                          Everybody's Talkin' at Me
# 113                                             4 + 20
# 114                                          Word Game
# 115                                        Buyin' Time
# 116                                  Midnight in Paris
# 117                                  Different Tongues
# 118                                            Soldier
# 119                                    Stateline Blues
# 120                                      Closer to You
# 121                                       No Me Niegas
# 122                                       Ring of Love
# 123                                           Circlin'
# 124                           Love the One You're With
# 125                                  It Doesn't Matter
# 126                                We Are Not Helpless
# 127                                           Marianne
# 128                                      Bound to Fall
# 129                                    Change Partners
# 130                                       Go Back Home
# 131                                    Johnny's Garden
# 132                Rock & Roll Crazies/Cuban Bluegrass
# 133                                  Sit Yourself Down
# 134                              You Can't Dance Alone
# 135                                   Thoroughfare Gap
# 136                                      We Will Go On
# 137                                     Beaucoup Yumbo
# 138                                     Midnight Rider
# 139                                        Woman Lleva
# 140                                            Lowdown
# 141                                      Not Fade Away
# 142                                 Can't Get No Booty
# 143                                              50/50
# 144                                           Stranger
# 145                                      Flaming Heart
# 146                                         Love Again
# 147                                       Can't Let Go
# 148                                      Grey to Green
# 149                     Only Love Can Break Your Heart
# 150                                    No Hiding Place
# 151                                       Right by You
# 152                                        Isn't It So
# 153                                Everybody's Talkin'
# 154                                Just Isn't Like You
# 155                                         In My Life
# 156                             Ballad of Hollis Brown
# 157                                       Singin' Call
# 158                                     The Right Girl
# 159                               Blind Fiddler Medley
# 160                                           Amazonia
# 161                                      Treetop Flyer
# 162                                   As I Come of Age
# 163                                         In the Way
# 164                                           New Mama
# 165                                    Cold Cold World
# 166                                         Love Story
# 167                                Turn Back The Pages
# 168                                 First Things First
# 169                                    Stateline Blues
# 170                                          The Loner
# 171                                        Buyin' Time
# 172                                            Soldier
# 173                                      Closer To You
# 174                                       Ring of Love
# 175                                           Circlin'
# 176                                     Midnight Rider
# 177                                      Not Fade Away
# 178                                 Can't Get No Booty
# 179                                   What's The Game?
# 180                                   Thoroughfare Gap
# 181                                     Beaucoup Yumbo
# 182                                  You Don't Love Me
# 183   It Takes a Lot to Laugh, It Takes a Train to Cry
# 184                                    Ain't It Always
# 185                                    Feed the People
# 186                                        Hearts Gate
# 187                                     Round the Bend
# 188                                     I Don't Get It
# 189                                          Around Us
# 190                                    Ole Man Trouble
# 191                                      Different Man
# 192                                        Piece of Me
# 193                                      Wounded World
# 194                                    Drivin' Thunder
# 195                                          Acadienne
# 196                                      Spanish Suite
# 197                     All I Know Is What You Tell Me
# 198                                So Begins the Task
# 199                                   Change Partners
# 200  Know You've Got to Run  forStephen Stills 2as ...
# 201                        The Doctor Will See You Now
# 202                                       Black Queen
# 203          Bumblebee (Do You Need a Place to Hide?)
# 204                                 Dreaming of Snakes
# 205                             Suite: Judy Blue Eyes
# 206                                 Helplessly Hoping
# 207                                      Wooden Ships
# 208                                     Treetop Flyer
# 209                                      Treetop Flyer
# 210                                               4+20
# 211                                    Johnny's Garden
# 212                                    Change Partners
# 213                        Girl from the North Country
# 214                                      Blind Fiddler
# 215                                Isn't It About Time
# 216                                  Rock & Roll Woman
# 217                                  Wrong Thing to Do
# 218                 Wounded World / Rocky Mountain Way
# 219                                           Bluebird
# 220                                For What It's Worth
# 221                           Love the One You're With
# 222                                   Handle with Care
# 223                                 So Begins the Task
# 224                                      River of Gold
# 225                                               Judy
# 226                                    Everybody Knows
# 227                                             Houses
# 228                                  Reason to Believe
# 229                        Girl from the North Country
# 230                      Who Knows Where the Time Goes
# 231                                          Questions
# 232                                   Military Madness
# 233                                        Better Days
# 234                                       Wounded Bird
# 235                                I Used to Be a King
# 236                                         Simple Man
# 237                                  Man in the Mirror
# 238                                   There's Only One
# 239                                         Sleep Song
# 240                                            Chicago
# 241                                        Earth & Sky
# 242                                      Love Has Come
# 243                                  Out on the Island
# 244                                           Skychild
# 245                                     Barrel of Pain
# 246                                           TV Guide
# 247                                     It's All Right
# 248                                      Magical Child
# 249                                  See You in Prague
# 250                                  Keep Away from Me
# 251                                      Innocent Eyes
# 252                                      Chippin' Away
# 253                        Don't Listen to the Rumours
# 254                                           Sad Eyes
# 255                                             Newday
# 256                                    Glass and Steel
# 257                                Dirty Little Secret
# 258                                   Blizzard of Lies
# 259                                   Lost Another One
# 260                                  The Chelsea Hotel
# 261                              I'll Be There for You
# 262                               Nothing in the World
# 263                            Where Love Lies Tonight
# 264                                            Pavanne
# 265                                   Liar's Nightmare
# 266                                  This Path Tonight
# 267                                     Myself at Last
# 268                                 Cracks in the City
# 269                                  Beneath the Waves
# 270                                    Fire Down Below
# 271                               Another Broken Heart
# 272                                             Target
# 273                                        Golden Days
# 274                                          Back Home
# 275                                             Encore
# 276                                Mississippi Burning
# 277                             Watch Out for the Wind
# 278                                          Right Now
# 279                                      A Better Life
# 280                                       Golden Idols
# 281                                    Stars & Stripes
# 282                                       Love of Mine
# 283                                Theme from Pastoral
# 284                                         In a Dream
# 285                                           Stand Up
# 286                                 It Feels Like Home
# 287                                       Buddy's Back
# 288                                  Follow Your Heart
# 289                         I Watched It All Come Down
# 290                               When It Comes to You
# 291                              The Old Country Waltz
# 292                             Saddle Up the Palomino
# 293                                           Hey Babe
# 294                                Hold Back the Tears
# 295                                  Star of Bethlehem
# 296                                       Will to Love
# 297                                   Like a Hurricane
# 298                Betty Lou's Got a New Pair of Shoes
# 299                                Rainin' in My Heart
# 300                                       Payola Blues
# 301                                          Wonderin'
# 302                                      Jellyroll Man
# 303                            Bright Lights, Big City
# 304                                      Cry, Cry, Cry
# 305                                      Mystery Train
# 306                                Weight of the World
# 307                                       Violent Side
# 308                                       Hippie Dream
# 309                                      Bad News Beat
# 310                               People on the Street
# 311                                  Hard Luck Stories
# 312                                    I Got a Problem
# 313                                           Pressure
# 314                                    Ten Men Workin'
# 315                                This Note's for You
# 316                                     Coupe de Ville
# 317                                   Life in the City
# 318                                           Twilight
# 319                                        Married Man
# 320                                       Sunny Inside
# 321                           Can't Believe Your Lyin'
# 322                                            Hey Hey
# 323          Rockin' in the Free World (Live acoustic)
# 324           Crime in the City (Sixty to Zero Part I)
# 325                                          Don't Cry
# 326                                  Hangin' on a Limb
# 327                                           Eldorado
# 328                                   The Ways of Love
# 329                                            Someday
# 330                                        On Broadway
# 331                                      Wrecking Ball
# 332                                            No More
# 333                                       Too Far Gone
# 334                                     Unknown Legend
# 335                               From Hank to Hendrix
# 336                                         You and Me
# 337                                       Harvest Moon
# 338                                         War of Man
# 339                                  One of These Days
# 340                                       Such a Woman
# 341                                           Old King
# 342                                       Dreamin' Man
# 343                                             Song X
# 344                                        Act of Love
# 345                                      I'm the Ocean
# 346                                  Big Green Country
# 347                                     Truth Be Known
# 348                                           Downtown
# 349                            What Happened Yesterday
# 350                                     Peace and Love
# 351                             Throw Your Hatred Down
# 352                                            Scenery
# 353                                    Good to See You
# 354                                      Silver & Gold
# 355                                 Daddy Went Walkin'
# 356                          Buffalo Springfield Again
# 357                                   The Great Divide
# 358                                      Horseshoe Man
# 359                                            Red Sun
# 360                                     Distant Camera
# 361                                         Razor Love
# 362                                        The Painter
# 363                                          No Wonder
# 364                  Falling Off the Face of the Earth
# 365                                      Far From Home
# 366                                       It's a Dream
# 367                                       Prairie Wind
# 368                                       Here for You
# 369                                    This Old Guitar
# 370                                    He Was the King
# 371                                   When God Made Me
# 372                                   After the Garden
# 373                                    Living with War
# 374                              The Restless Consumer
# 375                                      Shock and Awe
# 376                                           Families
# 377                                   Flags of Freedom
# 378                        Let's Impeach the President
# 379                               Lookin' for a Leader
# 380                                      Roger and Out
# 381                                 Beautiful Bluebird
# 382                                             Boxcar
# 383                                    Ordinary People
# 384                                      Shining Light
# 385                                       The Believer
# 386                                        Spirit Road
# 387                                      Dirty Old Man
# 388                                         Ever After
# 389                                     No Hidden Path
# 390                                When Worlds Collide
# 391                                          Fuel Line
# 392                                Just Singing a Song
# 393                                       Johnny Magic
# 394                                 Cough Up the Bucks
# 395                               Get Behind the Wheel
# 396                                       Off the Road
# 397                                       Hit the Road
# 398                                     Light a Candle
# 399                                       Walk with Me
# 400                                       Sign of Love
# 401                         Someone's Gonna Rescue You
# 402                                       Love and War
# 403                                        Angry World
# 404                                         Hitchhiker
# 405                          Peaceful Valley Boulevard
# 406                                A Letter Home Intro
# 407                                            Changes
# 408                        Girl from the North Country
# 409                                    Needle of Death
# 410                                 Early Morning Rain
# 411                                              Crazy
# 412                                  Reason to Believe
# 413                                  On the Road Again
# 414                          If You Could Read My Mind
# 415                               Since I Met You Baby
# 416                                        My Hometown
# 417                                Blowin' in the Wind
# 418                       Plastic Flowers (Orchestral)
# 419                 Who's Gonna Stand Up? (Orchestral)
# 420                  I Want to Drive My Car (Big Band)
# 421                               Glimmer (Orchestral)
# 422                    Say Hello to Chicago (Big Band)
# 423                            Tumbleweed (Orchestral)
# 424                     Like You Used to Do (Big Band)
# 425                  I'm Glad I Found You (Orchestral)
# 426             When I Watch You Sleeping (Orchestral)
# 427                                    Plastic Flowers
# 428                              Who's Gonna Stand Up?
# 429                             I Want to Drive My Car
# 430                                            Glimmer
# 431                               Say Hello to Chicago
# 432                                         Tumbleweed
# 433                                Like You Used to Do
# 434                               I'm Glad I Found You
# 435                          When I Watch You Sleeping
# 436                                Like You Used to Do
# 437                          When I Watch You Sleeping
# 438                             I Want to Drive My Car
# 439                                    Plastic Flowers
# 440                                            Glimmer
# 441                                   All Those Dreams
# 442                               Say Hello to Chicago
# 443                                         Tumbleweed
# 444                              Who's Gonna Stand Up?
# 445                                        Peace Trail
# 446                                 Can't Stop Workin'
# 447                                      Indian Givers
# 448                                            Show Me
# 449                                      Texas Rangers
# 450                     Terrorist Suicide Hang Gliders
# 451                                          John Oaks
# 452                                          My Pledge
# 453                                     Glass Accident
# 454                                      Already Great
# 455                                  Fly by Night Deal
# 456                                      Almost Always
# 457                                         Stand Tall
# 458                                    Change of Heart
# 459                                           Carnival
# 460                                     Diggin' a Hole
# 461                                Children of Destiny
# 462                                  When Bad Got Good
# 463                      Mother Earth (Natural Anthem)
# 464                                       Seed Justice
# 465                                    My Country Home
# 466                                 The Monsanto Years
# 467                                       Western Hero
# 468                                      Vampire Blues
# 469                                       Hippie Dream
# 470                                After the Gold Rush
# 471                                            Big Box
# 472                     People Want to Hear About Love
# 473                                          Wolf Moon
# 474                                      I'm the Ocean
# 475                                          Homefires
# 476                                             Burned
# 477                                    On the Way Home
# 478                                    If You Got Love
# 479                              A Dream That Can Last
# 480                                              Birds
# 481                                           My Heart
# 482                         When I Hold You in My Arms
# 483                                       Mother Earth
# 484                                           Mr. Soul
# 485                                       Comes a Time
# 486                                  Don't Forget Love
# 487          Rockin' in the Free World (Live acoustic)
# 488           Crime in the City (Sixty to Zero Part I)
# 489                                          Don't Cry
# 490                                  Hangin' on a Limb
# 491                                           Eldorado
# 492                                   The Ways of Love
# 493                                            Someday
# 494                                        On Broadway
# 495                                      Wrecking Ball
# 496                                            No More
# 497                                       Too Far Gone
# 498                                      Buffalo Stomp
# 499                                Ode to Wild Bill #1
# 500                           All Along the Watchtower
# 501                      Lucy in the Sky with Diamonds
# 502                                Ode to Wild Bill #2
# 503                           Papa Was a Rollin' Stone
# 504                            Home, Home on the Range
# 505                        Straight Answers (dialogue)
# 506                               Highway 61 Revisited
# 507        I Can't Help Myself (Sugar Pie Honey Bunch)
# 508                                Ode to Wild Bill #3
# 509                                  Keep on Chooglin'
# 510                                Ode to Wild Bill #4
# 511                                        Purple Haze
# 512                              Buffalo Stomp Refrain
# 513                                 Guitar Solo, No. 1
# 514              The Round Stones Beneath the Earth...
# 515                                 Guitar Solo, No. 2
# 516              Why Dost Thou Hide Thyself, Clouds...
# 517                                         Organ Solo
# 518                Do You Know How to Use This Weapon?
# 519                                 Guitar Solo, No. 3
# 520                                     Nobody's Story
# 521                                 Guitar Solo, No. 4
# 522                                Stupid White Men...
# 523                                 Guitar Solo, No. 5
# 524            Time for You to Leave, William Blake...
# 525                                 Guitar Solo, No. 6
# 526                         Theme from Dead Man (Edit)
# 527  Theme from Dead Man (Edit w/Johnny Deppspoken ...
# 528                 Theme from Dead Man (Long version)
# 529                       Many Moons Ago in the Future
# 530                                            Show Me
# 531                                  Paradox Passage 1
# 532                                                Hey
# 533                                  Paradox Passage 2
# 534                       Diggin' in the Dirt - Chorus
# 535                                  Paradox Passage 3
# 536                                        Peace Trail
# 537                                         Pocahontas
# 538                                        Cowgirl Jam
# 539               Angel Flying Too Close to the Ground
# 540                                  Paradox Passage 4
# 541                                Diggin' in the Dirt
# 542                                  Paradox Passage 5
# 543                        Running to the Silver Eagle
# 544                       Baby What You Want Me to Do?
# 545                                  Paradox Passage 6
# 546                                          Offerings
# 547                                          How Long?
# 548                                     Happy Together
# 549                                        Tell Me Why
# 550                     Only Love Can Break Your Heart
# 551                                After the Gold Rush
# 552                                   Expecting to Fly
# 553                              Bad Fog of Loneliness
# 554                                            Old Man
# 555                                              Birds
# 556                        Don't Let It Bring You Down
# 557                          See the Sky About to Rain
# 558                                      Cinnamon Girl
# 559                                       I Am a Child
# 560                                  Down by the River
# 561                                         Pocahontas
# 562                                       Powderfinger
# 563                                    Captain Kennedy
# 564                                             Hawaii
# 565                                   Give Me Strength
# 566                                      Ride My Llama
# 567                                         Hitchhiker
# 568                                         Campaigner
# 569                                      Human Highway
# 570                                              Intro
# 571                                Tonight's the Night
# 572                                Roll Out the Barrel
# 573                                     Mellow My Mind
# 574                                  World on a String
# 575                                         Band Intro
# 576                                       Speakin' Out
# 577                                      Candy Bar Rap
# 578                                        Albuquerque
# 579                                     Perry Como Rap
# 580                                           New Mama
# 581                                   David Geffen Rap
# 582                 Roll Another Number (For the Road)
# 583                                    Candy Bar 2 Rap
# 584                                         Tired Eyes
# 585                      Tonight's the Night – Part II
# 586                                            Walk On
# 587                                              Outro
# 588                               Songs for Judy Intro
# 589                                       Too Far Gone
# 590                               No One Seems to Know
# 591                                      Heart of Gold
# 592                                         White Line
# 593                                     Love Is a Rose
# 594                                After the Gold Rush
# 595                                      Human Highway
# 596                                        Tell Me Why
# 597                                           Mr. Soul
# 598                                     Mellow My Mind
# 599                                   Give Me Strength
# 600                                 A Man Needs a Maid
# 601                 Roll Another Number (for the Road)
# 602                           Journey Through the Past
# 603                                            Harvest
# 604                                         Campaigner
# 605          Old Laughing Lady (includes Guilty Train)
# 606                    The Losing End (When You're on)
# 607                           Here We Are in the Years
# 608                     The Needle and the Damage Done
# 609                                         Pocahontas
# 610                                   Long May You Run
# 611                                   Make Love to You
# 612                                Midnight on the Bay
# 613                                        Black Coral
# 614                                         Ocean Girl
# 615                                       Let It Shine
# 616                          12/8 Blues (All the Same)
# 617                                      Fontainebleau
# 618                                     Guardian Angel
# 619                                   Southbound Train
# 620                                        Whole Cloth
# 621                                         Blacknotes
# 622                                    Stranger's Room
# 623                                   Where Will I Be?
# 624                                      Frozen Smiles
# 625                                              Games
# 626                              Girl to Be on My Mind
# 627                                      The Wall Song
# 628                                          Spotlight
# 629                                        Broken Bird
# 630                                    Time After Time
# 631                              Dancer (instrumental)
# 632                                       J.B.'s Blues
# 633                                         Marguerita
# 634                                       Taken at All
# 635                                        Foolish Man
# 636                                        Lay Me Down
# 637                                          Puppeteer
# 638                           Through Here Quite Often
# 639                                              Grace
# 640                                       Jesus of Rio
# 641                                        I Surrender
# 642                                        Luck Dragon
# 643                          On the Other Side of Town
# 644                                   Half Your Angels
# 645                                   They Want It All
# 646                                     Don't Dig Here
# 647                                  Milky Way Tonight
# 648                                            Charlie
# 649                             Penguin in a Palm Tree
# 650                              Michael (Hedges Here)
# 651                                            Samurai
# 652                             Shining on Your Dreams
# 653                                 Live on (the Wall)
# 654                                    Immigration Man
# 655                                      The Lee Shore
# 656                                I Used to Be a King
# 657                  King of the Mountain(bonus track)
# 658                                            Page 43
# 659                                         Simple Man
# 660                                        Foolish Man
# 661                           Bittersweet(bonus track)
# 662                                          Mama Lion
# 663                                      Love Work Out
# 664                                      The Wall Song
# 665                                         Wild Tales
# 666                                           Carry Me
# 667                                   Southbound Train
# 668                                           Laughing
# 669                                            Chicago
# 670                                        Bittersweet
# 671                                 anticipatory crowd
# 672                                            Déjà Vu
# 673                                       Wooden Ships
# 674                                  Man in the Mirror
# 675                                I Used to Be A King
# 676                               Traction in the Rain
# 677                                      The Lee Shore
# 678                                   Southbound Train
# 679                                           Laughing
# 680                                              Triad
# 681                                   Where Will I Be?
# 682                                     Strangers Room
# 683                                    Immigration Man
# 684                                         Guinnevere
# 685                                Teach Your Children
# 686                              Suite: Judy Blue Eyes
# 687                                  Marrakesh Express
# 688                                         Guinnevere
# 689                              You Don't Have to Cry
# 690                                     Pre-Road Downs
# 691                                       Wooden Ships
# 692                                 Lady of the Island
# 693                                  Helplessly Hoping
# 694                                     Long Time Gone
# 695                                        49 Bye-Byes
# 696                           Do for the Others (demo)
# 697           Song with No Words (Tree with No Leaves)
# 698                                Everybody's Talkin'
# 699                         Teach Your Children (demo)
# 700                                           Carry On
# 701                                Teach Your Children
# 702                                 Almost Cut My Hair
# 703                                           Helpless
# 704                                            Déjà Vu
# 705                                          Our House
# 706                                             4 + 20
# 707  Country Girla. Whiskey Boot Hillb. Down, Down,...
# 708                               Everybody I Love You
# 709                                          Our House
# 710                                             4 + 20
# 711           Song With No Words (Tree With No Leaves)
# 712                                              Birds
# 713                 So Begins the Task / Hold On Tight
# 714                             Right Between the Eyes
# 715                                 Almost Cut My Hair
# 716                                Teach Your Children
# 717                                  How Have You Been
# 718                                              Triad
# 719                         Horses Through a Rainstorm
# 720                                Know You Got to Run
# 721                                       Question Why
# 722                                           Laughing
# 723                                She Can't Handle It
# 724                                         Sleep Song
# 725                                            Déjà Vu
# 726                                   Everyday We Live
# 727                                      The Lee Shore
# 728                                      I'll Be There
# 729                                  Bluebird Revisted
# 730                         Horses Through a Rainstorm
# 731                                     30 Dollar Fine
# 732                                        Ivory Tower
# 733                                      Same Old Song
# 734                    Hold On Tight / Change Partners
# 735                                           Laughing
# 736                                     Shadow Captain
# 737                                    See the Changes
# 738                                       Carried Away
# 739                                          Fair Game
# 740                                    Anything at All
# 741                                          Dark Star
# 742                            Just a Song Before I Go
# 743                                     Run from Tears
# 744                                          Cold Rain
# 745                                       In My Dreams
# 746                             Turn Your Back on Love
# 747                                  Wasted on the Way
# 748                                     Southern Cross
# 749                                  Into the Darkness
# 750                                    Since I Met You
# 751                              Too Much Love to Hide
# 752                                     Song for Susan
# 753                                      You Are Alive
# 754                     Might As Well Have a Good Time
# 755                                      Raise a Voice
# 756                                     Feel Your Love
# 757                            Tomorrow Is Another Day
# 758                                     American Dream
# 759                                        Got It Made
# 760                                       Name of Love
# 761                                  Don't Say Goodbye
# 762                                     This Old House
# 763                         Nighttime for the Generals
# 764                                         Shadowland
# 765                                    Drivin' Thunder
# 766                                   Clear Blue Skies
# 767                                          That Girl
# 768                                            Compass
# 769                                  Soldiers of Peace
# 770                                     Feel Your Love
# 771                                         Night Song
# 772                                         Live It Up
# 773                             If Anybody Had a Heart
# 774                                             Tomboy
# 775                            Haven't We Lost Enough?
# 776                                 (Got to Keep) Open
# 777                                      Straight Line
# 778                             House of Broken Dreams
# 779                                             Arrows
# 780                               Only Waiting for You
# 781                                       Find a Dream
# 782                                             Camera
# 783                                       Unequal Love
# 784                                     Till It Shines
# 785                                   It Won't Go Away
# 786                                   These Empty Days
# 787                                         In My Life
# 788                                  Street to Lean On
# 789                                           Bad Boyz
# 790                                    After the Storm
# 791                                        Faith in Me
# 792                                    Looking Forward
# 793                               Stand and Be Counted
# 794                                          Heartland
# 795                                        Seen Enough
# 796                                           Slowpoke
# 797                                      Dream for Him
# 798                                      No Tears Left
# 799                                     Out of Control
# 800                                       Someday Soon
# 801                                  Queen of Them All
#
#                                         album release_date  \
# 0                                Oh Yes I Can   1989-23-01
# 1                                Oh Yes I Can   1989-23-01
# 2                                Oh Yes I Can   1989-23-01
# 3                                Oh Yes I Can   1989-23-01
# 4                                Oh Yes I Can   1989-23-01
# 5                                Oh Yes I Can   1989-23-01
# 6                                Oh Yes I Can   1989-23-01
# 7                                Oh Yes I Can   1989-23-01
# 8                                Oh Yes I Can   1989-23-01
# 9                                Oh Yes I Can   1989-23-01
# 10                             Thousand Roads   1993-04-05
# 11                             Thousand Roads   1993-04-05
# 12                             Thousand Roads   1993-04-05
# 13                             Thousand Roads   1993-04-05
# 14                             Thousand Roads   1993-04-05
# 15                             Thousand Roads   1993-04-05
# 16                             Thousand Roads   1993-04-05
# 17                             Thousand Roads   1993-04-05
# 18                             Thousand Roads   1993-04-05
# 19                                       Croz   2014-28-01
# 20                                       Croz   2014-28-01
# ...
# 522                                         Neil Young
# 523                                         Neil Young
# 524                                         Neil Young
# 525                                         Neil Young
# 526                                         Neil Young
# 527                                         Neil Young
# 528                                         Neil Young
# 529                                         Neil Young
# 530                                         Neil Young
# 531                                         Neil Young
# 532                                         Neil Young
# 533                                         Neil Young
# 534                                         Neil Young
# 535                                         Neil Young
# 536                                         Neil Young
# 537                                         Neil Young
# 538                                         Neil Young
# 539                                         Neil Young
# 540                                         Neil Young
# 541                                         Neil Young
# 542                                         Neil Young
# 543                                         Neil Young
# 544                                         Neil Young
# 545                                         Neil Young
# 546                                         Neil Young
# 547                                         Neil Young
# 548                                         Neil Young
# 549                                         Neil Young
# 550                                         Neil Young
# 551                                         Neil Young
# 552                                         Neil Young
# 553                                         Neil Young
# 554                                         Neil Young
# 555                                         Neil Young
# 556                                         Neil Young
# 557                                         Neil Young
# 558                                         Neil Young
# 559                                         Neil Young
# 560                                         Neil Young
# 561                                         Neil Young
# 562                                         Neil Young
# 563                                         Neil Young
# 564                                         Neil Young
# 565                                         Neil Young
# 566                                         Neil Young
# 567                                         Neil Young
# 568                                         Neil Young
# 569                                         Neil Young
# 570                                         Neil Young
# 571                                         Neil Young
# 572                                         Neil Young
# 573                                         Neil Young
# 574                                         Neil Young
# 575                                         Neil Young
# 576                                         Neil Young
# 577                                         Neil Young
# 578                                         Neil Young
# 579                                         Neil Young
# 580                                         Neil Young
# 581                                         Neil Young
# 582                                         Neil Young
# 583                                         Neil Young
# 584                                         Neil Young
# 585                                         Neil Young
# 586                                         Neil Young
# 587                                         Neil Young
# 588                                         Neil Young
# 589                                         Neil Young
# 590                                         Neil Young
# 591                                         Neil Young
# 592                                         Neil Young
# 593                                         Neil Young
# 594                                         Neil Young
# 595                                         Neil Young
# 596                                         Neil Young
# 597                                         Neil Young
# 598                                         Neil Young
# 599                                         Neil Young
# 600                                         Neil Young
# 601                                         Neil Young
# 602                                         Neil Young
# 603                                         Neil Young
# 604                                         Neil Young
# 605                                         Neil Young
# 606                                         Neil Young
# 607                                         Neil Young
# 608                                         Neil Young
# 609                                         Neil Young
# 610  Neil Young, Stephen Stills, Joe Lala, Joe Vita...
# 611  Stephen Stills, Neil Young, Joe Lala, Joe Vita...
# 612  Neil Young, Stephen Stills, Joe Lala, Joe Vita...
# 613  Stephen Stills, Neil Young, Joe Lala, Joe Vita...
# 614  Neil Young, Stephen Stills, Joe Lala, Joe Vita...
# 615  Neil Young, Stephen Stills, Joe Vitale, George...
# 616  Stephen Stills, Neil Young, Joe Lala, Joe Vita...
# 617  Neil Young, Stephen Stills, Joe Lala, Joe Vita...
# 618  Stephen Stills, Neil Young, Joe Lala, Joe Vita...
# 619                                      Crosby & Nash
# 620                                      Crosby & Nash
# 621                                      Crosby & Nash
# 622                                      Crosby & Nash
# 623                                      Crosby & Nash
# 624                                      Crosby & Nash
# 625                                      Crosby & Nash
# 626                                      Crosby & Nash
# 627                                      Crosby & Nash
# 628                                      Crosby & Nash
# 629                                      Crosby & Nash
# 630                                      Crosby & Nash
# 631                                      Crosby & Nash
# 632                                      Crosby & Nash
# 633                                      Crosby & Nash
# 634                                      Crosby & Nash
# 635                                      Crosby & Nash
# 636                                      Crosby & Nash
# 637                                      Crosby & Nash
# 638                                      Crosby & Nash
# 639                                      Crosby & Nash
# 640                                      Crosby & Nash
# 641                                      Crosby & Nash
# 642                                      Crosby & Nash
# 643                                      Crosby & Nash
# 644                                      Crosby & Nash
# 645                                      Crosby & Nash
# 646                                      Crosby & Nash
# 647                                      Crosby & Nash
# 648                                      Crosby & Nash
# 649                                      Crosby & Nash
# 650                                      Crosby & Nash
# 651                                      Crosby & Nash
# 652                                      Crosby & Nash
# 653                                      Crosby & Nash
# 654                                      Crosby & Nash
# 655                                      Crosby & Nash
# 656                                      Crosby & Nash
# 657                                      Crosby & Nash
# 658                                      Crosby & Nash
# 659                                      Crosby & Nash
# 660                                      Crosby & Nash
# 661                                      Crosby & Nash
# 662                                      Crosby & Nash
# 663                                      Crosby & Nash
# 664                                      Crosby & Nash
# 665                                      Crosby & Nash
# 666                                      Crosby & Nash
# 667                                      Crosby & Nash
# 668                                      Crosby & Nash
# 669                                      Crosby & Nash
# 670                                      Crosby & Nash
# 671                                      Crosby & Nash
# 672                                      Crosby & Nash
# 673                                      Crosby & Nash
# 674                                      Crosby & Nash
# 675                                      Crosby & Nash
# 676                                      Crosby & Nash
# 677                                      Crosby & Nash
# 678                                      Crosby & Nash
# 679                                      Crosby & Nash
# 680                                      Crosby & Nash
# 681                                      Crosby & Nash
# 682                                      Crosby & Nash
# 683                                      Crosby & Nash
# 684                                      Crosby & Nash
# 685                                      Crosby & Nash
# 686                                             Stills
# 687                                               Nash
# 688                                       Crosby, Nash
# 689                              Stills, Crosby & Nash
# 690                                               Nash
# 691                                     Crosby, Stills
# 692                                               Nash
# 693                              Stills, Crosby & Nash
# 694                                     Crosby, Stills
# 695                                             Stills
# 696                                    Stills and Nash
# 697                                    Crosby and Nash
# 698                            Stills, Crosby and Nash
# 699                                    Nash and Crosby
# 700                                             Stills
# 701                                               Nash
# 702                                             Crosby
# 703                                              Young
# 704                                             Crosby
# 705                                               Nash
# 706                                             Stills
# 707                       Young, Crosby, Stills & Nash
# 708                              Stills, Crosby & Nash
# 709                                                NaN
# 710                                                NaN
# 711                                                NaN
# 712                                                NaN
# 713                                                NaN
# 714                                                NaN
# 715                                                NaN
# 716                                                NaN
# 717                                                NaN
# 718                                                NaN
# 719                                                NaN
# 720                                                NaN
# 721                                                NaN
# 722                                                NaN
# 723                                                NaN
# 724                                                NaN
# 725                                                NaN
# 726                                                NaN
# 727                                                NaN
# 728                                                NaN
# 729                                                NaN
# 730                                                NaN
# 731                                                NaN
# 732                                                NaN
# 733                                                NaN
# 734                                                NaN
# 735                                                NaN
# 736                              Crosby, Stills & Nash
# 737                              Stills, Crosby & Nash
# 738                                       Nash, Crosby
# 739                              Stills, Crosby & Nash
# 740                                             Crosby
# 741                                             Stills
# 742                                               Nash
# 743                                             Stills
# 744                                               Nash
# 745                                             Crosby
# 746                                                NaN
# 747                                                NaN
# 748                                                NaN
# 749                                                NaN
# 750                                                NaN
# 751                                                NaN
# 752                                                NaN
# 753                                                NaN
# 754                                                NaN
# 755                                                NaN
# 756                                                NaN
# 757                                                NaN
# 758                                                NaN
# 759                                                NaN
# 760                                                NaN
# 761                                                NaN
# 762                                                NaN
# 763                                                NaN
# 764                                                NaN
# 765                                                NaN
# 766                                                NaN
# 767                                                NaN
# 768                                                NaN
# 769                                                NaN
# 770                                                NaN
# 771                                                NaN
# 772                                               Nash
# 773                                               Nash
# 774                                             Stills
# 775                              Stills, Crosby & Nash
# 776                                             Stills
# 777                                               Nash
# 778                                               Nash
# 779                                             Crosby
# 780                                             Stills
# 781                                               Nash
# 782                                             Crosby
# 783                                               Nash
# 784                                             Crosby
# 785                                     Stills, Crosby
# 786                              Stills, Crosby & Nash
# 787                              Crosby, Stills & Nash
# 788                                             Crosby
# 789                                             Stills
# 790                                               Nash
# 791                                             Stills
# 792                       Young, Crosby, Stills & Nash
# 793                                             Crosby
# 794                                               Nash
# 795                                             Stills
# 796                                              Young
# 797                                             Crosby
# 798                                             Stills
# 799                                              Young
# 800                              Nash, Crosby & Stills
# 801                                              Young

# %% [markdown]
# ## Merge all DataFrames to 'wikipedia-v3.csv'

# %%
# stills_young_wiki = pd.read_csv('/content/drive/MyDrive/Eksplorativna analiza podataka sa Spotify-a/Wikipedia Web Scraping/Wikipedia Datasets/raw/wikipedia-stills-young-band.csv')
# david_crosby_wiki = pd.read_csv('/content/drive/MyDrive/Eksplorativna analiza podataka sa Spotify-a/Wikipedia Web Scraping/Wikipedia Datasets/v3/wikipedia-david-crosby-v3.csv')
# stephen_stills_wiki = pd.read_csv('/content/drive/MyDrive/Eksplorativna analiza podataka sa Spotify-a/Wikipedia Web Scraping/Wikipedia Datasets/v3/wikipedia-stephen-stills-v3.csv')
# graham_nash_wiki = pd.read_csv('/content/drive/MyDrive/Eksplorativna analiza podataka sa Spotify-a/Wikipedia Web Scraping/Wikipedia Datasets/v3/wikipedia-graham-nash-v3.csv')
# neil_young_wiki = pd.read_csv('/content/drive/MyDrive/Eksplorativna analiza podataka sa Spotify-a/Wikipedia Web Scraping/Wikipedia Datasets/v3/wikipedia-neil-young-v3.csv')
# crosby_nash_wiki = pd.read_csv('/content/drive/MyDrive/Eksplorativna analiza podataka sa Spotify-a/Wikipedia Web Scraping/Wikipedia Datasets/v3/wikipedia-crosby-nash-v3.csv')
# csn_csny_wiki = pd.read_csv('/content/drive/MyDrive/Eksplorativna analiza podataka sa Spotify-a/Wikipedia Web Scraping/Wikipedia Datasets/v3/wikipedia-csn-csny-v3.csv')
# wikipedia_v3 = pd.concat([david_crosby_wiki,
#                          stephen_stills_wiki,
#                          graham_nash_wiki,
#                          neil_young_wiki,
#                          stills_young_wiki,
#                          crosby_nash_wiki,
#                          csn_csny_wiki
#                          ]).reset_index(drop=True)
# wikipedia_v3.to_csv('wikipedia-v3.csv', index=False)
# wikipedia_v3
